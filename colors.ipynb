# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('cleaned_titanicdata.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
x=df['Age']
y=df['Fare']
colors=["red"]
colors2=["blue"]

# %%
plt.scatter(x,y)

# %%
plt.title('AGE & FARE')
plt.xlabel=('Age')
plt.ylabel('Fare')
plt.scatter(x,y)

# %%
plt.title('AGE & FARE')
plt.xlabel=('Age')
plt.ylabel('Fare')
plt.scatter(x,y, c='red',label='Age')
plt.scatter(x,y, c='blue',label='Fare', alpha=0.5)

plt.legend(['Age (red)','Fare (green)'])

plt.show()
